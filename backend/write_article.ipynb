# %%
from main import find_trending_content, generate_articles_from_trending_content
import database as db
import json
# Out:
# /Users/yuanjihome/Library/CloudStorage/GoogleDrive-linayqiu2@gmail.com/My Drive/Ji&Chun/consumer_recommendation/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# An error occurred: module 'importlib.metadata' has no attribute 'packages_distributions'
# Database initialized successfully.
# YOUTUBE_API_KEY loaded: True
# OPENAI_API_KEY loaded: True
# SUPADATA_API_KEY loaded: True
# TAVILY_API_KEY loaded: True
# ...

# %%
topic_meta_data = find_trending_content(
    topics=['Beauty'],
    timeframe="month",
    max_videos_per_topic=20,
    country='US',
    save_to_db=True,
    query= None, #"(EV OR Tesla OR Rivian OR Lucid OR Mercedes EV) AND (review OR testing OR tests OR tour)",
    video_duration= "medium,long",
    use_llm_queries=True
)
# Out:
# === Finding Trending Topics ===
# Topics: ['Beauty']
# Timeframe: month, Country: US
#   Fetching videos for 'Beauty' (Topic IDs: ['/m/019_rr', '/m/0kt51'])...
#     Error fetching videos for 'Beauty': <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?part=snippet&topicId=%2Fm%2F019_rr&q=Beauty+review+OR+unboxing+OR+hands-on&type=video&order=viewCount&publishedAfter=2025-12-05T04%3A37%3A47Z&maxResults=5&videoDuration=medium&key=AIzaSyDQY4qzRlM_SPJ6Jz6QDda3wY4f2jYS17Y&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
#     Fetching web data for topic: Beauty...
#     💾 Saved topic to database: ID=36

# %%
topic_meta_data
# Out:
# {'topics': [{'topic_name': 'Beauty',
#    'topic_id': '/m/019_rr',
#    'video_ids': [],
#    'web_data': [{'title': 'My first MINI BEAUTY PR unboxing is HERE Skincare ...',
#      'url': 'https://www.instagram.com/reel/DRLDQRmgG9J/',
#      'content': 'Join me in this exciting beauty unboxing experience as I reveal a curated selection of luxury skincare, makeup, and haircare products from',
#      'score': 0.9981178},
#     {'title': 'Beauty on Review',
#      'url': 'https://www.beautyonreview.com/',
#      'content': "In this guide, you'll find makeup, skincare and bodycare for all budgets. Have a read and hopefully it will make you feel inspired.",
#      'score': 0.99632156},
#     {'title': "Video: Unboxing Smashbox's 25th Anniversary Lip Palette",
#      'url': 'https://www.ellecanada.com/beauty/video-unboxing-smashbox-s-25th-anniversary-lip-palette',
# ...
